# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyDUcX1WEs2D-5ybuOP41vwT5WXz4KwFBMQ"

# %%
model = ChatGoogleGenerativeAI(
    model = "gemini-2.5-flash",
    temperature = 0
)

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str
    rateing: int

# %%
def create_outline(state: BlogState)-> BlogState:

    # fetch title
    title = state['title']

    #call llm gen outline
    prompt = f'Generate an outline for a blog in the topic - {title}'
    outline = model.invoke(prompt).content

    #update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState)-> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title  - {title} using the following outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
def rate_blog(state: BlogState)-> BlogState:
    title = state['title']
    outline = state['outline']
    content = state['content']

    prompt = f'Based on this outline - {outline} rate my blog for this title - {title} & generate a digital score'

    rateing = model.invoke(prompt).content

    state['rateing'] = rateing

    return state

# %%
graph = StateGraph(BlogState)

#nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)
graph.add_node('rate_blog', rate_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', 'rate_blog')
graph.add_edge('rate_blog', END)

graph.compile()
workflow = graph.compile()

# %%
initial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/anaconda3/envs/langgraph/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:3047, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3046 try:
# -> 3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
#
# File ~/anaconda3/envs/langgraph/lib/python3.11/site-packages/google/genai/models.py:5227, in Models.generate_content(self, model, contents, config)
#    5226 i += 1
# -> 5227 response = self._generate_content(
#    5228     model=model, contents=contents, config=parsed_config
#    5229 )
#    5231 function_map = _extra_utils.get_function_map(parsed_config)
#
# ...

# %%
print(final_state['rateing'])
# Out:
# This outline is **exceptionally well-crafted and comprehensive**. It provides a robust framework for a highly engaging, informative, and impactful blog post.
#
# Here's a detailed breakdown and your "Digital Score":
#
# ---
#
# ## Rating of the Blog Post Outline: "Rise of AI in India"
#
# **Overall Assessment:**
# This outline is a masterclass in blog post planning. It demonstrates a deep understanding of the topic, the target audience, and best practices for content creation, SEO, and engagement. The structure is logical, the content suggestions are rich with detail and examples, and it covers all critical aspects from drivers to challenges and unique contributions.
#
# **Strengths:**
#
# 1.  **Exceptional Structure:** The flow from introduction to detailed body paragraphs, challenges, and a strong conclusion is impeccable. Each section builds logically on the last.
# ...

# %%
print(final_state['outline'])
# Out:
# Okay, here's a comprehensive outline for a blog post on "The Rise of AI in India," designed to be engaging, informative, and well-structured.
#
# ---
#
# ## Blog Post Outline: The AI Awakening: How India is Embracing and Shaping the Future of Artificial Intelligence
#
# **Target Audience:** Tech enthusiasts, business leaders, policymakers, students, and anyone interested in India's technological advancements.
#
# **Tone:** Optimistic, analytical, informative, slightly forward-looking.
#
# ---
#
# ### I. Catchy Title Options:
#
# *   The AI Awakening: How India is Embracing and Shaping the Future of Artificial Intelligence
# *   India's AI Ascent: From Emerging Tech to Global Powerhouse
# *   Beyond the Hype: Unpacking India's Rapid Rise in the AI Landscape
# *   The Silicon Valley of AI? India's Bold Leap into Artificial Intelligence
# *   Driving the Digital Revolution: India's Pivotal Role in the Global AI Era
#
# ### II. Introduction (Approx. 150-200 words)
#
# ...

# %%
print(final_state['content'])
# Out:
# ## The AI Awakening: How India is Embracing and Shaping the Future of Artificial Intelligence
#
# Artificial Intelligence is no longer a futuristic concept; it's a present-day reality reshaping industries, economies, and daily lives worldwide. From powering personalized recommendations to revolutionizing medical diagnostics, AI's transformative power is undeniable. Amidst this global technological shift, India is rapidly emerging not just as a consumer of AI, but as a significant contributor and innovator. With its vast talent pool, burgeoning digital infrastructure, and an insatiable entrepreneurial spirit, India is uniquely positioned to leverage AI for widespread impact. This blog explores the multifaceted rise of AI in India, examining the key drivers, transformative applications, unique innovations, and the challenges that lie ahead as India carves its niche as a significant force in the AI revolution.
#
# ### The Driving Forces Behind India's AI Surge
#
# ...
